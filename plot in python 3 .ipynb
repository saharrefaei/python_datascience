# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings 
warnings.filterwarnings("ignore","use_inf_as_na")

iris = sns.load_dataset('iris')
print(iris)
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
# Create a scatter plot using Matplotlib
plt.scatter(iris['sepal_length'], iris['sepal_width'], c=iris['species'].astype('category').cat.codes, cmap='viridis')
plt.xlabel('Sepal Length (cm)')
plt.ylabel('Sepal Width (cm)')
plt.title('Scatter Plot of Sepal Length vs Sepal Width')
plt.colorbar(label='Species')
plt.show()

# %%
# Create a scatter plot using Matplotlib
plt1=iris.plot.scatter(x='sepal_length', y='sepal_width')
plt1.set_label('Sepal Length (cm)')
plt1.set_ylabel('Sepal Width (cm)')
plt1.set_title('Scatter Plot of Sepal Length vs Sepal Width')
plt.show()

# %%
fix , ax = plt.subplots()
colors = {"setosa":"blue", "versicolor" :"red" , "virginica" : "black" }
for Spieces , data in iris.groupby("species"):
    data.plot(kind='scatter',x="sepal_length", y='sepal_width',color=colors[Spieces],ax=ax)


plt.title('Histogram of Sepal Length')
plt.xlabel('Sepal Length (cm)')
plt.ylabel('Frequency')
plt.show()

# %%
fix , ax = plt.subplots()
colors = {"setosa":"blue", "versicolor" :"red" , "virginica" : "black" }
for Spieces , data in iris.groupby("species"):
    data.plot(kind='scatter',x="sepal_length", y='sepal_width',color=colors[Spieces],ax=ax ,marker='+')
for Spieces , data in iris.groupby("species"):
    data.plot(kind='scatter',x="petal_length", y='petal_width',color=colors[Spieces],ax=ax,marker='*')


plt.title('Histogram of Sepal Length')
plt.xlabel('Sepal Length (cm)')
plt.ylabel('Frequency')
plt.show()

# %%
sns.scatterplot(data=iris, x='sepal_length', y='sepal_width', hue='species', style='species',palette = "deep")
plt.show()

# %%
sns.pairplot(iris, hue='species')
plt.show()

# %%
# Create iris_1 DataFrame
iris_1 = pd.DataFrame(data=iris[['sepal_length', 'sepal_width', 'species']])
iris_1['measured'] = 'sepal'
iris_1.columns = ["length", "width", "species", "measured"]

# Create iris_2 DataFrame
iris_2 = pd.DataFrame(data=iris[['petal_length', 'petal_width', 'species']])
iris_2['measured'] = 'petal'
iris_2.columns = ["length", "width", "species", "measured"]

# Concatenate iris_1 and iris_2
iris2 = pd.concat([iris_1, iris_2])

# Plot the scatterplot
sns.scatterplot(data=iris2, x='width', y='length', hue='species', style='measured')
plt.show()
